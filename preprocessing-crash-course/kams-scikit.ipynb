# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data = np.random.randint(0,100,(10,2))

# %%
data
# Out:
# array([[57, 86],
#        [31, 35],
#        [77, 73],
#        [46, 58],
#        [25, 58],
#        [27, 52],
#        [80, 52],
#        [93, 79],
#        [46, 72],
#        [66, 91]])

# %%
scaler_model = MinMaxScaler()

# %%
scaler_model.fit_transform(data)
# Out:
# array([[0.47058824, 0.91071429],
#        [0.08823529, 0.        ],
#        [0.76470588, 0.67857143],
#        [0.30882353, 0.41071429],
#        [0.        , 0.41071429],
#        [0.02941176, 0.30357143],
#        [0.80882353, 0.30357143],
#        [1.        , 0.78571429],
#        [0.30882353, 0.66071429],
#        [0.60294118, 1.        ]])

# %%
import pandas as pd

# %%
mydata = np.random.randint(0,100,(50,4))
data = pd.DataFrame(data =mydata , columns =['f1','f2','f3','label'])

# %%
data
# Out:
#     f1  f2  f3  label
# 0   56  38  72     35
# 1   36  58  79     58
# 2   24  39  51     20
# 3   54  88  63     94
# 4   45  85  72     68
# 5   82  96   4     76
# 6   20  59  38     36
# 7   60  23  21      2
# 8   14  19  57     66
# 9   81  69  77     60
# 10  11  54   5     18
# 11  23   8  30     26
# 12  22   3  47     87
# 13   7  27  60     86
# 14  87  15  26     59
# 15  58  55  45     16
# 16  67   7  63     79
# 17  83  27  38     35
# 18  92  43  52     12
# 19  79  83  67     84
# 20  62  80  49     30
# 21  72  18  41     51
# 22  19  27  63      9
# 23  16  80  90     81
# 24  60  73  27     78
# 25  55   2  12     83
# 26  32  88  70     10
# 27  22   7  28     74
# 28  46  66  43     93
# 29   5  71  25      0
# 30  35  53  72     18
# 31  63  35  35     18
# 32  64   5  51     70
# 33   6  52  45     58
# 34  61  68  47     20
# 35  58   7   2     43
# 36  41   1   2     98
# 37  39   0  92     58
# 38  49  83  34     20
# 39  63  65  24     83
# 40  68  99   6     70
# 41  79  94  80     20
# 42  56  82  19     62
# 43  24  76  19     64
# 44  15   1  31      0
# 45  56  32  86     59
# 46  67  91  83     88
# 47  83  99   7     94
# 48  62  97  50     97
# 49  98  61  42     42

# %%
X = data [['f1','f2','f3']]

# %%
y = data['label']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (35, 3)
